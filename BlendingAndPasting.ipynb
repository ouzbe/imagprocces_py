# %% [markdown]
# <a href="https://colab.research.google.com/github/ouzbe/imagprocces_py/blob/main/BlendingAndPasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img1 = cv2.imread('Honey_Badger.jpg')

# %%
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.imread('watermark_no_copy.png')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (720, 1280, 3)

# %%
img2.shape
# Out:
# (1920, 1915, 3)

# %%
img2 = cv2.resize(img2,(384,383))

# %%
img1=cv2.resize(img1,(1200,1200))
img2=cv2.resize(img2,(1200,1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended = cv2.addWeighted(src1=img1,alpha= 0.8,src2=img2,beta=0.1,gamma =10)

# %%
plt.imshow(blended)

# %%
img1 = cv2.imread('Honey_Badger.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.imread('watermark_no_copy.png')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.resize (img2,(600,600))

# %%
plt.imshow(img2)

# %%
large_img=img1
small_img= img2

# %%
x_offset =0
y_offset= 0

# %%
x_end=x_offset+small_img.shape[1]
y_end=y_offset+small_img.shape[0]

# %%
small_img.shape
# Out:
# (600, 600, 3)

# %%
large_img[y_offset:y_end,x_offset:x_end] = small_img

# %%
plt.imshow(large_img)

# %%
img1 = cv2.imread('Honey_Badger.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.imread('watermark_no_copy.png')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.resize(img2,(300,300))
img2.shape
# Out:
# (300, 300, 3)

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (720, 1280, 3)

# %%
x_offset = 1280-300
y_offset = 720-300

# %%
rows,cols,chanels=img2.shape

# %%
roi = img1[y_offset:720,x_offset:1280]

# %%
plt.imshow(roi)

# %%
img2gray = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap='gray')

# %%
mask_inv = cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv, cmap='gray')

# %%
mask_inv.shape
# Out:
# (300, 300)

# %%
import numpy as np

# %%
white_background = np.full(img2.shape , 255 , dtype= np.uint8)

# %%
new_mask_inv= mask_inv[:,:,np.newaxis]

# %%
new_mask_inv.shape
# Out:
# (300, 300, 1)

# %%
# white_background

# %%
bk = cv2.bitwise_or(white_background,white_background,mask=mask_inv)

# %%
plt.imshow(bk)

# %%
fg = cv2.bitwise_or(img2,img2, mask=mask_inv)

# %%
plt.imshow(fg)
